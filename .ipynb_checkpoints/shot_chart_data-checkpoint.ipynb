# %%
# %matplotlib inline
import requests
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import urllib.request
from bs4 import BeautifulSoup

# %%
url_start = 'https://stats.nba.com/stats/shotchartdetail?AheadBehind=&CFID=33&CFPARAMS=2017-18&ClutchTime=&Conference=&ContextFilter=&ContextMeasure=FGA&DateFrom=&DateTo=&Division=&EndPeriod=10&EndRange=28800&GROUP_ID=&GameEventID=&GameID=&GameSegment=&GroupID=&GroupMode=&GroupQuantity=5&LastNGames=0&LeagueID=00&Location=&Month=0&OnOff=&OpponentTeamID=0&Outcome=&PORound=0&Period=0&PlayerID='
url_end = '&PlayerID1=&PlayerID2=&PlayerID3=&PlayerID4=&PlayerID5=&PlayerPosition=&PointDiff=&Position=&RangeType=0&RookieYear=&Season=2017-18&SeasonSegment=&SeasonType=Regular+Season&ShotClockRange=&StartPeriod=1&StartRange=0&StarterBench=&TeamID=0&VsConference=&VsDivision=&VsPlayerID1=&VsPlayerID2=&VsPlayerID3=&VsPlayerID4=&VsPlayerID5=&VsTeamID='
headers = {
    'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.87 Safari/537.36',
}

# %%
def get_shot_data(player_id, season):
    url_start = f'https://stats.nba.com/stats/shotchartdetail?AheadBehind=&CFID=33&CFPARAMS={season}&ClutchTime=&Conference=&ContextFilter=&ContextMeasure=FGA&DateFrom=&DateTo=&Division=&EndPeriod=10&EndRange=28800&GROUP_ID=&GameEventID=&GameID=&GameSegment=&GroupID=&GroupMode=&GroupQuantity=5&LastNGames=0&LeagueID=00&Location=&Month=0&OnOff=&OpponentTeamID=0&Outcome=&PORound=0&Period=0&PlayerID='
    url_end = f'&PlayerID1=&PlayerID2=&PlayerID3=&PlayerID4=&PlayerID5=&PlayerPosition=&PointDiff=&Position=&RangeType=0&RookieYear=&Season={season}&SeasonSegment=&SeasonType=Regular+Season&ShotClockRange=&StartPeriod=1&StartRange=0&StarterBench=&TeamID=0&VsConference=&VsDivision=&VsPlayerID1=&VsPlayerID2=&VsPlayerID3=&VsPlayerID4=&VsPlayerID5=&VsTeamID='
    headers = {
        'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.87 Safari/537.36',
    }
    full_url = url_start + str(player_id) + url_end
    json_dat = requests.get(full_url, headers=headers).json()
    return(json_dat)

# %%
player_id=2544
season='2017-18'
url_start = f'https://stats.nba.com/stats/shotchartdetail?AheadBehind=&CFID=33&CFPARAMS={season}&ClutchTime=&Conference=&ContextFilter=&ContextMeasure=FGA&DateFrom=&DateTo=&Division=&EndPeriod=10&EndRange=28800&GROUP_ID=&GameEventID=&GameID=&GameSegment=&GroupID=&GroupMode=&GroupQuantity=5&LastNGames=0&LeagueID=00&Location=&Month=0&OnOff=&OpponentTeamID=0&Outcome=&PORound=0&Period=0&PlayerID='
url_end = f'&PlayerID1=&PlayerID2=&PlayerID3=&PlayerID4=&PlayerID5=&PlayerPosition=&PointDiff=&Position=&RangeType=0&RookieYear=&Season={season}&SeasonSegment=&SeasonType=Regular+Season&ShotClockRange=&StartPeriod=1&StartRange=0&StarterBench=&TeamID=0&VsConference=&VsDivision=&VsPlayerID1=&VsPlayerID2=&VsPlayerID3=&VsPlayerID4=&VsPlayerID5=&VsTeamID='
headers = {
    'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.87 Safari/537.36',
}
full_url = url_start + str(player_id) + url_end
full_url
# Out:
# 'https://stats.nba.com/stats/shotchartdetail?AheadBehind=&CFID=33&CFPARAMS=2017-18&ClutchTime=&Conference=&ContextFilter=&ContextMeasure=FGA&DateFrom=&DateTo=&Division=&EndPeriod=10&EndRange=28800&GROUP_ID=&GameEventID=&GameID=&GameSegment=&GroupID=&GroupMode=&GroupQuantity=5&LastNGames=0&LeagueID=00&Location=&Month=0&OnOff=&OpponentTeamID=0&Outcome=&PORound=0&Period=0&PlayerID=2544&PlayerID1=&PlayerID2=&PlayerID3=&PlayerID4=&PlayerID5=&PlayerPosition=&PointDiff=&Position=&RangeType=0&RookieYear=&Season=2017-18&SeasonSegment=&SeasonType=Regular+Season&ShotClockRange=&StartPeriod=1&StartRange=0&StarterBench=&TeamID=0&VsConference=&VsDivision=&VsPlayerID1=&VsPlayerID2=&VsPlayerID3=&VsPlayerID4=&VsPlayerID5=&VsTeamID='

# %%
json_dat = get_shot_data(player_id=2544, season='2017-18')
json_dat
# Out:
# {'Message': 'An error has occurred.'}

# %%
player_id=204001
req_params = {
    'Season': '2017-18',
    'SeasonType': 'Regular Season',
    'TeamID': 0,
    'PlayerID': player_id,
    'GameID': None,
    'Outcome': None,
    'Location': None,
    'Month': 0,
    'SeasonSegment': None,
    'DateFrom': None,
    'DateTo': None,
    'OpponentTeamID': 0,
    'VsConference': None,
    'VsDivision': None,
    'Position': None,
    'RookieYear': None,
    'GameSegment': None,
    'Period': 0,
    'LastNGames': 0,
    'ClutchTime': None,
    'AheadBehind': None,
    'PointDiff': None,
    'RangeType': 0,
    'StartPeriod': 1,
    'EndPeriod': 10,
    'StartRange': 0,
    'EndRange': 28800,
    'ContextFilter': "SEASON_YEAR='2017-18'",
    'ContextMeasure': 'FGA'
}

url = 'https://stats.nba.com/stats/shotchartdetail'

dat = requests.get(url, params=req_params, headers=headers)
dat
# Out:
# <Response [400]>

# %%
json_dat
# Out:
# {'resource': 'shotchartdetail',
#  'parameters': {'LeagueID': '00',
#   'Season': '2017-18',
#   'SeasonType': 'Regular Season',
#   'TeamID': 0,
#   'PlayerID': 204001,
#   'GameID': None,
#   'Outcome': None,
#   'Location': None,
#   'Month': 0,
#   'SeasonSegment': None,
#   'DateFrom': None,
#   'DateTo': None,
#   'OpponentTeamID': 0,
#   'VsConference': None,
#   'VsDivision': None,
#   'Position': None,
#   'RookieYear': None,
#   'GameSegment': None,
#   'Period': 0,
#   'LastNGames': 0,
#   'ClutchTime': None,
#   'AheadBehind': None,
#   'PointDiff': None,
#   'RangeType': 0,
#   'StartPeriod': 1,
#   'EndPeriod': 10,
#   'StartRange': 0,
#   'EndRange': 28800,
#   'ContextFilter': "SEASON_YEAR='2017-18'",
#   'ContextMeasure': 'FGA'},
#  'resultSets': [{'name': 'Shot_Chart_Detail',
#    'headers': ['GRID_TYPE',
#     'GAME_ID',
#     'GAME_EVENT_ID',
#     'PLAYER_ID',
#     'PLAYER_NAME',
#     'TEAM_ID',
#     'TEAM_NAME',
#     'PERIOD',
#     'MINUTES_REMAINING',
#     'SECONDS_REMAINING',
#     'EVENT_TYPE',
#     'ACTION_TYPE',
#     'SHOT_TYPE',
#     'SHOT_ZONE_BASIC',
#     'SHOT_ZONE_AREA',
#     'SHOT_ZONE_RANGE',
#     'SHOT_DISTANCE',
#     'LOC_X',
#     'LOC_Y',
#     'SHOT_ATTEMPTED_FLAG',
#     'SHOT_MADE_FLAG',
#     'GAME_DATE',
#     'HTM',
#     'VTM'],
#    'rowSet': [['Shot Chart Detail',
#      '0021700015',
#      45,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      8,
#      32,
#      'Missed Shot',
#      'Turnaround Fadeaway shot',
#      '2PT Field Goal',
#      'In The Paint (Non-RA)',
#      'Center(C)',
#      'Less Than 8 ft.',
#      5,
#      0,
#      58,
#      1,
#      0,
#      '20171019',
#      'OKC',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700015',
#      64,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      7,
#      26,
#      'Made Shot',
#      'Jump Shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Left Side(L)',
#      '16-24 ft.',
#      21,
#      -193,
#      90,
#      1,
#      1,
#      '20171019',
#      'OKC',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700015',
#      85,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      5,
#      41,
#      'Missed Shot',
#      'Jump Shot',
#      '3PT Field Goal',
#      'Above the Break 3',
#      'Center(C)',
#      '24+ ft.',
#      24,
#      2,
#      249,
#      1,
#      0,
#      '20171019',
#      'OKC',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700015',
#      166,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      0,
#      30,
#      'Made Shot',
#      'Running Layup Shot',
#      '2PT Field Goal',
#      'In The Paint (Non-RA)',
#      'Center(C)',
#      'Less Than 8 ft.',
#      4,
#      -23,
#      36,
#      1,
#      1,
#      '20171019',
#      'OKC',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700015',
#      181,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      0,
#      3,
#      'Made Shot',
#      'Pullup Jump shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Center(C)',
#      '16-24 ft.',
#      18,
#      -28,
#      186,
#      1,
#      1,
#      '20171019',
#      'OKC',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700015',
#      202,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      2,
#      10,
#      30,
#      'Made Shot',
#      'Jump Shot',
#      '3PT Field Goal',
#      'Above the Break 3',
#      'Right Side Center(RC)',
#      '24+ ft.',
#      24,
#      125,
#      216,
#      1,
#      1,
#      '20171019',
#      'OKC',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700015',
#      209,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      2,
#      9,
#      54,
#      'Missed Shot',
#      'Driving Floating Jump Shot',
#      '2PT Field Goal',
#      'In The Paint (Non-RA)',
#      'Center(C)',
#      '8-16 ft.',
#      12,
#      19,
#      125,
#      1,
#      0,
#      '20171019',
#      'OKC',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700015',
#      222,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      2,
#      9,
#      3,
#      'Made Shot',
#      'Turnaround Jump Shot',
#      '2PT Field Goal',
#      'Restricted Area',
#      'Center(C)',
#      'Less Than 8 ft.',
#      1,
#      5,
#      16,
#      1,
#      1,
#      '20171019',
#      'OKC',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700015',
#      239,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      2,
#      7,
#      34,
#      'Missed Shot',
#      'Turnaround Jump Shot',
#      '2PT Field Goal',
#      'In The Paint (Non-RA)',
#      'Center(C)',
#      'Less Than 8 ft.',
#      5,
#      -23,
#      55,
#      1,
#      0,
#      '20171019',
#      'OKC',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700015',
#      285,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      2,
#      5,
#      0,
#      'Made Shot',
#      'Driving Floating Bank Jump Shot',
#      '2PT Field Goal',
#      'In The Paint (Non-RA)',
#      'Center(C)',
#      'Less Than 8 ft.',
#      7,
#      75,
#      26,
#      1,
#      1,
#      '20171019',
#      'OKC',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700015',
#      308,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      2,
#      2,
#      43,
#      'Made Shot',
#      'Putback Layup Shot',
#      '2PT Field Goal',
#      'Restricted Area',
#      'Center(C)',
#      'Less Than 8 ft.',
#      1,
#      -9,
#      7,
#      1,
#      1,
#      '20171019',
#      'OKC',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700015',
#      316,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      2,
#      1,
#      44,
#      'Missed Shot',
#      'Jump Shot',
#      '3PT Field Goal',
#      'Above the Break 3',
#      'Left Side Center(LC)',
#      '24+ ft.',
#      25,
#      -158,
#      194,
#      1,
#      0,
#      '20171019',
#      'OKC',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700015',
#      326,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      2,
#      1,
#      15,
#      'Missed Shot',
#      'Driving Hook Shot',
#      '2PT Field Goal',
#      'In The Paint (Non-RA)',
#      'Center(C)',
#      '8-16 ft.',
#      10,
#      -32,
#      95,
#      1,
#      0,
#      '20171019',
#      'OKC',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700015',
#      344,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      2,
#      1,
#      8,
#      'Missed Shot',
#      'Putback Dunk Shot',
#      '2PT Field Goal',
#      'Restricted Area',
#      'Center(C)',
#      'Less Than 8 ft.',
#      3,
#      -9,
#      32,
#      1,
#      0,
#      '20171019',
#      'OKC',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700015',
#      386,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      3,
#      10,
#      33,
#      'Missed Shot',
#      'Turnaround Jump Shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Right Side(R)',
#      '8-16 ft.',
#      9,
#      89,
#      24,
#      1,
#      0,
#      '20171019',
#      'OKC',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700015',
#      410,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      3,
#      7,
#      47,
#      'Made Shot',
#      'Fadeaway Jump Shot',
#      '2PT Field Goal',
#      'In The Paint (Non-RA)',
#      'Center(C)',
#      'Less Than 8 ft.',
#      6,
#      -2,
#      64,
#      1,
#      1,
#      '20171019',
#      'OKC',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700015',
#      421,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      3,
#      6,
#      55,
#      'Missed Shot',
#      'Pullup Jump shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Left Side(L)',
#      '8-16 ft.',
#      15,
#      -119,
#      99,
#      1,
#      0,
#      '20171019',
#      'OKC',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700015',
#      450,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      3,
#      5,
#      7,
#      'Missed Shot',
#      'Jump Shot',
#      '3PT Field Goal',
#      'Above the Break 3',
#      'Center(C)',
#      '24+ ft.',
#      25,
#      -19,
#      258,
#      1,
#      0,
#      '20171019',
#      'OKC',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700015',
#      454,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      3,
#      4,
#      59,
#      'Missed Shot',
#      'Layup Shot',
#      '2PT Field Goal',
#      'Restricted Area',
#      'Center(C)',
#      'Less Than 8 ft.',
#      1,
#      6,
#      11,
#      1,
#      0,
#      '20171019',
#      'OKC',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700015',
#      536,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      11,
#      40,
#      'Made Shot',
#      'Cutting Layup Shot',
#      '2PT Field Goal',
#      'Restricted Area',
#      'Center(C)',
#      'Less Than 8 ft.',
#      0,
#      -5,
#      4,
#      1,
#      1,
#      '20171019',
#      'OKC',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700015',
#      582,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      7,
#      53,
#      'Missed Shot',
#      'Jump Shot',
#      '3PT Field Goal',
#      'Above the Break 3',
#      'Left Side Center(LC)',
#      '24+ ft.',
#      24,
#      -227,
#      100,
#      1,
#      0,
#      '20171019',
#      'OKC',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700015',
#      588,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      7,
#      42,
#      'Made Shot',
#      'Jump Shot',
#      '3PT Field Goal',
#      'Above the Break 3',
#      'Right Side Center(RC)',
#      '24+ ft.',
#      25,
#      187,
#      179,
#      1,
#      1,
#      '20171019',
#      'OKC',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700015',
#      604,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      6,
#      31,
#      'Made Shot',
#      'Dunk Shot',
#      '2PT Field Goal',
#      'Restricted Area',
#      'Center(C)',
#      'Less Than 8 ft.',
#      0,
#      -4,
#      3,
#      1,
#      1,
#      '20171019',
#      'OKC',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700015',
#      631,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      3,
#      59,
#      'Missed Shot',
#      'Jump Bank Shot',
#      '2PT Field Goal',
#      'Restricted Area',
#      'Center(C)',
#      'Less Than 8 ft.',
#      1,
#      18,
#      8,
#      1,
#      0,
#      '20171019',
#      'OKC',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700015',
#      652,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      2,
#      55,
#      'Missed Shot',
#      'Putback Dunk Shot',
#      '2PT Field Goal',
#      'Restricted Area',
#      'Center(C)',
#      'Less Than 8 ft.',
#      0,
#      0,
#      -6,
#      1,
#      0,
#      '20171019',
#      'OKC',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700030',
#      18,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      10,
#      35,
#      'Made Shot',
#      'Turnaround Fadeaway Bank Jump Shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Right Side(R)',
#      '8-16 ft.',
#      12,
#      90,
#      81,
#      1,
#      1,
#      '20171021',
#      'NYK',
#      'DET'],
#     ['Shot Chart Detail',
#      '0021700030',
#      79,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      5,
#      13,
#      'Made Shot',
#      'Jump Shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Right Side(R)',
#      '8-16 ft.',
#      13,
#      96,
#      91,
#      1,
#      1,
#      '20171021',
#      'NYK',
#      'DET'],
#     ['Shot Chart Detail',
#      '0021700030',
#      83,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      4,
#      35,
#      'Made Shot',
#      'Turnaround Fadeaway shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Left Side(L)',
#      '8-16 ft.',
#      9,
#      -94,
#      26,
#      1,
#      1,
#      '20171021',
#      'NYK',
#      'DET'],
#     ['Shot Chart Detail',
#      '0021700030',
#      128,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      1,
#      58,
#      'Made Shot',
#      'Jump Shot',
#      '2PT Field Goal',
#      'In The Paint (Non-RA)',
#      'Center(C)',
#      '8-16 ft.',
#      12,
#      16,
#      123,
#      1,
#      1,
#      '20171021',
#      'NYK',
#      'DET'],
#     ['Shot Chart Detail',
#      '0021700030',
#      216,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      2,
#      7,
#      4,
#      'Made Shot',
#      'Driving Layup Shot',
#      '2PT Field Goal',
#      'Restricted Area',
#      'Center(C)',
#      'Less Than 8 ft.',
#      2,
#      -17,
#      13,
#      1,
#      1,
#      '20171021',
#      'NYK',
#      'DET'],
#     ['Shot Chart Detail',
#      '0021700030',
#      231,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      2,
#      5,
#      50,
#      'Made Shot',
#      'Jump Shot',
#      '3PT Field Goal',
#      'Above the Break 3',
#      'Left Side Center(LC)',
#      '24+ ft.',
#      25,
#      -155,
#      202,
#      1,
#      1,
#      '20171021',
#      'NYK',
#      'DET'],
#     ['Shot Chart Detail',
#      '0021700030',
#      235,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      2,
#      5,
#      16,
#      'Made Shot',
#      'Jump Shot',
#      '3PT Field Goal',
#      'Above the Break 3',
#      'Left Side Center(LC)',
#      '24+ ft.',
#      25,
#      -127,
#      226,
#      1,
#      1,
#      '20171021',
#      'NYK',
#      'DET'],
#     ['Shot Chart Detail',
#      '0021700030',
#      301,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      2,
#      1,
#      8,
#      'Missed Shot',
#      'Jump Shot',
#      '3PT Field Goal',
#      'Above the Break 3',
#      'Center(C)',
#      '24+ ft.',
#      34,
#      105,
#      331,
#      1,
#      0,
#      '20171021',
#      'NYK',
#      'DET'],
#     ['Shot Chart Detail',
#      '0021700030',
#      308,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      2,
#      0,
#      42,
#      'Made Shot',
#      'Dunk Shot',
#      '2PT Field Goal',
#      'Restricted Area',
#      'Center(C)',
#      'Less Than 8 ft.',
#      0,
#      -1,
#      6,
#      1,
#      1,
#      '20171021',
#      'NYK',
#      'DET'],
#     ['Shot Chart Detail',
#      '0021700030',
#      316,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      2,
#      0,
#      0,
#      'Missed Shot',
#      'Jump Shot',
#      '3PT Field Goal',
#      'Backcourt',
#      'Back Court(BC)',
#      'Back Court Shot',
#      53,
#      -117,
#      525,
#      1,
#      0,
#      '20171021',
#      'NYK',
#      'DET'],
#     ['Shot Chart Detail',
#      '0021700030',
#      373,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      3,
#      7,
#      55,
#      'Missed Shot',
#      'Jump Shot',
#      '3PT Field Goal',
#      'Backcourt',
#      'Back Court(BC)',
#      'Back Court Shot',
#      49,
#      5,
#      492,
#      1,
#      0,
#      '20171021',
#      'NYK',
#      'DET'],
#     ['Shot Chart Detail',
#      '0021700030',
#      395,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      3,
#      6,
#      25,
#      'Missed Shot',
#      'Jump Shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Center(C)',
#      '16-24 ft.',
#      20,
#      -62,
#      195,
#      1,
#      0,
#      '20171021',
#      'NYK',
#      'DET'],
#     ['Shot Chart Detail',
#      '0021700030',
#      403,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      3,
#      5,
#      19,
#      'Missed Shot',
#      'Jump Shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Center(C)',
#      '16-24 ft.',
#      20,
#      62,
#      197,
#      1,
#      0,
#      '20171021',
#      'NYK',
#      'DET'],
#     ['Shot Chart Detail',
#      '0021700030',
#      504,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      9,
#      6,
#      'Made Shot',
#      'Turnaround Jump Shot',
#      '2PT Field Goal',
#      'In The Paint (Non-RA)',
#      'Center(C)',
#      'Less Than 8 ft.',
#      6,
#      -32,
#      51,
#      1,
#      1,
#      '20171021',
#      'NYK',
#      'DET'],
#     ['Shot Chart Detail',
#      '0021700030',
#      516,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      7,
#      59,
#      'Missed Shot',
#      'Layup Shot',
#      '2PT Field Goal',
#      'Restricted Area',
#      'Center(C)',
#      'Less Than 8 ft.',
#      3,
#      -26,
#      17,
#      1,
#      0,
#      '20171021',
#      'NYK',
#      'DET'],
#     ['Shot Chart Detail',
#      '0021700030',
#      519,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      7,
#      27,
#      'Made Shot',
#      'Jump Shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Right Side(R)',
#      '8-16 ft.',
#      10,
#      105,
#      24,
#      1,
#      1,
#      '20171021',
#      'NYK',
#      'DET'],
#     ['Shot Chart Detail',
#      '0021700030',
#      538,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      5,
#      12,
#      'Made Shot',
#      'Jump Shot',
#      '3PT Field Goal',
#      'Above the Break 3',
#      'Center(C)',
#      '24+ ft.',
#      25,
#      52,
#      253,
#      1,
#      1,
#      '20171021',
#      'NYK',
#      'DET'],
#     ['Shot Chart Detail',
#      '0021700030',
#      551,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      4,
#      39,
#      'Missed Shot',
#      'Jump Shot',
#      '2PT Field Goal',
#      'In The Paint (Non-RA)',
#      'Left Side(L)',
#      '8-16 ft.',
#      8,
#      -80,
#      32,
#      1,
#      0,
#      '20171021',
#      'NYK',
#      'DET'],
#     ['Shot Chart Detail',
#      '0021700030',
#      565,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      2,
#      53,
#      'Missed Shot',
#      'Jump Shot',
#      '3PT Field Goal',
#      'Right Corner 3',
#      'Right Side(R)',
#      '24+ ft.',
#      24,
#      232,
#      64,
#      1,
#      0,
#      '20171021',
#      'NYK',
#      'DET'],
#     ['Shot Chart Detail',
#      '0021700030',
#      596,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      0,
#      37,
#      'Missed Shot',
#      'Driving Layup Shot',
#      '2PT Field Goal',
#      'Restricted Area',
#      'Center(C)',
#      'Less Than 8 ft.',
#      1,
#      -6,
#      13,
#      1,
#      0,
#      '20171021',
#      'NYK',
#      'DET'],
#     ['Shot Chart Detail',
#      '0021700051',
#      9,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      11,
#      30,
#      'Missed Shot',
#      'Step Back Jump shot',
#      '3PT Field Goal',
#      'Above the Break 3',
#      'Center(C)',
#      '24+ ft.',
#      27,
#      36,
#      269,
#      1,
#      0,
#      '20171024',
#      'BOS',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700051',
#      24,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      9,
#      41,
#      'Missed Shot',
#      'Driving Layup Shot',
#      '2PT Field Goal',
#      'Restricted Area',
#      'Center(C)',
#      'Less Than 8 ft.',
#      3,
#      -20,
#      25,
#      1,
#      0,
#      '20171024',
#      'BOS',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700051',
#      46,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      8,
#      32,
#      'Made Shot',
#      'Jump Shot',
#      '2PT Field Goal',
#      'In The Paint (Non-RA)',
#      'Center(C)',
#      '8-16 ft.',
#      14,
#      -51,
#      135,
#      1,
#      1,
#      '20171024',
#      'BOS',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700051',
#      57,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      7,
#      12,
#      'Missed Shot',
#      'Step Back Jump shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Center(C)',
#      '16-24 ft.',
#      22,
#      -9,
#      224,
#      1,
#      0,
#      '20171024',
#      'BOS',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700051',
#      97,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      4,
#      11,
#      'Missed Shot',
#      'Turnaround Fadeaway shot',
#      '2PT Field Goal',
#      'In The Paint (Non-RA)',
#      'Center(C)',
#      'Less Than 8 ft.',
#      7,
#      58,
#      53,
#      1,
#      0,
#      '20171024',
#      'BOS',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700051',
#      115,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      2,
#      44,
#      'Missed Shot',
#      'Driving Layup Shot',
#      '2PT Field Goal',
#      'In The Paint (Non-RA)',
#      'Left Side(L)',
#      '8-16 ft.',
#      9,
#      -71,
#      59,
#      1,
#      0,
#      '20171024',
#      'BOS',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700051',
#      247,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      2,
#      5,
#      12,
#      'Missed Shot',
#      'Pullup Jump shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Center(C)',
#      '8-16 ft.',
#      15,
#      -13,
#      155,
#      1,
#      0,
#      '20171024',
#      'BOS',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700051',
#      269,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      2,
#      3,
#      9,
#      'Missed Shot',
#      'Turnaround Fadeaway shot',
#      '2PT Field Goal',
#      'In The Paint (Non-RA)',
#      'Left Side(L)',
#      '8-16 ft.',
#      9,
#      -63,
#      66,
#      1,
#      0,
#      '20171024',
#      'BOS',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700051',
#      319,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      3,
#      10,
#      49,
#      'Missed Shot',
#      'Jump Shot',
#      '3PT Field Goal',
#      'Above the Break 3',
#      'Right Side Center(RC)',
#      '24+ ft.',
#      25,
#      113,
#      230,
#      1,
#      0,
#      '20171024',
#      'BOS',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700051',
#      334,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      3,
#      8,
#      44,
#      'Missed Shot',
#      'Fadeaway Jump Shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Left Side(L)',
#      '8-16 ft.',
#      11,
#      -116,
#      17,
#      1,
#      0,
#      '20171024',
#      'BOS',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700051',
#      353,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      3,
#      7,
#      55,
#      'Missed Shot',
#      'Driving Layup Shot',
#      '2PT Field Goal',
#      'Restricted Area',
#      'Center(C)',
#      'Less Than 8 ft.',
#      3,
#      21,
#      23,
#      1,
#      0,
#      '20171024',
#      'BOS',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700051',
#      420,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      3,
#      2,
#      51,
#      'Missed Shot',
#      'Layup Shot',
#      '2PT Field Goal',
#      'Restricted Area',
#      'Center(C)',
#      'Less Than 8 ft.',
#      2,
#      27,
#      11,
#      1,
#      0,
#      '20171024',
#      'BOS',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700051',
#      527,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      7,
#      11,
#      'Made Shot',
#      'Cutting Layup Shot',
#      '2PT Field Goal',
#      'In The Paint (Non-RA)',
#      'Center(C)',
#      'Less Than 8 ft.',
#      5,
#      54,
#      20,
#      1,
#      1,
#      '20171024',
#      'BOS',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700051',
#      536,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      6,
#      47,
#      'Made Shot',
#      'Turnaround Hook Shot',
#      '2PT Field Goal',
#      'In The Paint (Non-RA)',
#      'Center(C)',
#      'Less Than 8 ft.',
#      5,
#      48,
#      20,
#      1,
#      1,
#      '20171024',
#      'BOS',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700073',
#      7,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      11,
#      46,
#      'Made Shot',
#      'Turnaround Jump Shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Right Side(R)',
#      '8-16 ft.',
#      9,
#      88,
#      42,
#      1,
#      1,
#      '20171027',
#      'NYK',
#      'BKN'],
#     ['Shot Chart Detail',
#      '0021700073',
#      17,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      10,
#      48,
#      'Made Shot',
#      'Jump Shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Center(C)',
#      '16-24 ft.',
#      20,
#      22,
#      203,
#      1,
#      1,
#      '20171027',
#      'NYK',
#      'BKN'],
#     ['Shot Chart Detail',
#      '0021700073',
#      22,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      9,
#      46,
#      'Made Shot',
#      'Jump Shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Left Side(L)',
#      '8-16 ft.',
#      14,
#      -136,
#      60,
#      1,
#      1,
#      '20171027',
#      'NYK',
#      'BKN'],
#     ['Shot Chart Detail',
#      '0021700073',
#      33,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      8,
#      54,
#      'Missed Shot',
#      'Tip Layup Shot',
#      '2PT Field Goal',
#      'Restricted Area',
#      'Center(C)',
#      'Less Than 8 ft.',
#      0,
#      0,
#      -6,
#      1,
#      0,
#      '20171027',
#      'NYK',
#      'BKN'],
#     ['Shot Chart Detail',
#      '0021700073',
#      37,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      8,
#      41,
#      'Missed Shot',
#      'Jump Shot',
#      '3PT Field Goal',
#      'Above the Break 3',
#      'Right Side Center(RC)',
#      '24+ ft.',
#      26,
#      138,
#      224,
#      1,
#      0,
#      '20171027',
#      'NYK',
#      'BKN'],
#     ['Shot Chart Detail',
#      '0021700073',
#      47,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      7,
#      45,
#      'Missed Shot',
#      'Hook Shot',
#      '2PT Field Goal',
#      'Restricted Area',
#      'Center(C)',
#      'Less Than 8 ft.',
#      2,
#      5,
#      21,
#      1,
#      0,
#      '20171027',
#      'NYK',
#      'BKN'],
#     ['Shot Chart Detail',
#      '0021700073',
#      89,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      4,
#      10,
#      'Made Shot',
#      'Turnaround Fadeaway Bank Jump Shot',
#      '2PT Field Goal',
#      'In The Paint (Non-RA)',
#      'Right Side(R)',
#      '8-16 ft.',
#      10,
#      55,
#      93,
#      1,
#      1,
#      '20171027',
#      'NYK',
#      'BKN'],
#     ['Shot Chart Detail',
#      '0021700073',
#      92,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      3,
#      36,
#      'Missed Shot',
#      'Jump Shot',
#      '3PT Field Goal',
#      'Above the Break 3',
#      'Right Side Center(RC)',
#      '24+ ft.',
#      30,
#      166,
#      258,
#      1,
#      0,
#      '20171027',
#      'NYK',
#      'BKN'],
#     ['Shot Chart Detail',
#      '0021700073',
#      96,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      2,
#      52,
#      'Missed Shot',
#      'Jump Shot',
#      '3PT Field Goal',
#      'Above the Break 3',
#      'Center(C)',
#      '24+ ft.',
#      25,
#      -14,
#      258,
#      1,
#      0,
#      '20171027',
#      'NYK',
#      'BKN'],
#     ['Shot Chart Detail',
#      '0021700073',
#      226,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      2,
#      5,
#      34,
#      'Made Shot',
#      'Dunk Shot',
#      '2PT Field Goal',
#      'Restricted Area',
#      'Center(C)',
#      'Less Than 8 ft.',
#      0,
#      -6,
#      3,
#      1,
#      1,
#      '20171027',
#      'NYK',
#      'BKN'],
#     ['Shot Chart Detail',
#      '0021700073',
#      253,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      2,
#      3,
#      32,
#      'Missed Shot',
#      'Turnaround Fadeaway Bank Jump Shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Left Side(L)',
#      '8-16 ft.',
#      12,
#      -111,
#      62,
#      1,
#      0,
#      '20171027',
#      'NYK',
#      'BKN'],
#     ['Shot Chart Detail',
#      '0021700073',
#      264,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      2,
#      2,
#      42,
#      'Missed Shot',
#      'Jump Shot',
#      '3PT Field Goal',
#      'Above the Break 3',
#      'Right Side Center(RC)',
#      '24+ ft.',
#      24,
#      90,
#      232,
#      1,
#      0,
#      '20171027',
#      'NYK',
#      'BKN'],
#     ['Shot Chart Detail',
#      '0021700073',
#      276,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      2,
#      1,
#      59,
#      'Made Shot',
#      'Dunk Shot',
#      '2PT Field Goal',
#      'Restricted Area',
#      'Center(C)',
#      'Less Than 8 ft.',
#      2,
#      -11,
#      20,
#      1,
#      1,
#      '20171027',
#      'NYK',
#      'BKN'],
#     ['Shot Chart Detail',
#      '0021700073',
#      331,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      3,
#      10,
#      54,
#      'Made Shot',
#      'Putback Dunk Shot',
#      '2PT Field Goal',
#      'Restricted Area',
#      'Center(C)',
#      'Less Than 8 ft.',
#      0,
#      0,
#      -6,
#      1,
#      1,
#      '20171027',
#      'NYK',
#      'BKN'],
#     ['Shot Chart Detail',
#      '0021700073',
#      346,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      3,
#      9,
#      10,
#      'Made Shot',
#      'Turnaround Jump Shot',
#      '2PT Field Goal',
#      'In The Paint (Non-RA)',
#      'Left Side(L)',
#      '8-16 ft.',
#      12,
#      -67,
#      102,
#      1,
#      1,
#      '20171027',
#      'NYK',
#      'BKN'],
#     ['Shot Chart Detail',
#      '0021700073',
#      355,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      3,
#      8,
#      56,
#      'Missed Shot',
#      'Jump Shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Right Side Center(RC)',
#      '16-24 ft.',
#      16,
#      78,
#      143,
#      1,
#      0,
#      '20171027',
#      'NYK',
#      'BKN'],
#     ['Shot Chart Detail',
#      '0021700073',
#      359,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      3,
#      8,
#      17,
#      'Made Shot',
#      'Turnaround Jump Shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Left Side Center(LC)',
#      '16-24 ft.',
#      16,
#      -115,
#      117,
#      1,
#      1,
#      '20171027',
#      'NYK',
#      'BKN'],
#     ['Shot Chart Detail',
#      '0021700073',
#      498,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      11,
#      21,
#      'Made Shot',
#      'Jump Shot',
#      '3PT Field Goal',
#      'Above the Break 3',
#      'Center(C)',
#      '24+ ft.',
#      25,
#      -79,
#      247,
#      1,
#      1,
#      '20171027',
#      'NYK',
#      'BKN'],
#     ['Shot Chart Detail',
#      '0021700073',
#      502,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      10,
#      35,
#      'Made Shot',
#      'Fadeaway Jump Shot',
#      '2PT Field Goal',
#      'In The Paint (Non-RA)',
#      'Center(C)',
#      '8-16 ft.',
#      10,
#      -14,
#      101,
#      1,
#      1,
#      '20171027',
#      'NYK',
#      'BKN'],
#     ['Shot Chart Detail',
#      '0021700073',
#      517,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      9,
#      32,
#      'Missed Shot',
#      'Hook Shot',
#      '2PT Field Goal',
#      'In The Paint (Non-RA)',
#      'Center(C)',
#      'Less Than 8 ft.',
#      6,
#      59,
#      36,
#      1,
#      0,
#      '20171027',
#      'NYK',
#      'BKN'],
#     ['Shot Chart Detail',
#      '0021700073',
#      550,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      7,
#      11,
#      'Missed Shot',
#      'Jump Shot',
#      '3PT Field Goal',
#      'Above the Break 3',
#      'Right Side Center(RC)',
#      '24+ ft.',
#      28,
#      167,
#      232,
#      1,
#      0,
#      '20171027',
#      'NYK',
#      'BKN'],
#     ['Shot Chart Detail',
#      '0021700073',
#      556,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      6,
#      37,
#      'Made Shot',
#      'Putback Layup Shot',
#      '2PT Field Goal',
#      'Restricted Area',
#      'Center(C)',
#      'Less Than 8 ft.',
#      0,
#      0,
#      -6,
#      1,
#      1,
#      '20171027',
#      'NYK',
#      'BKN'],
#     ['Shot Chart Detail',
#      '0021700073',
#      594,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      5,
#      7,
#      'Missed Shot',
#      'Turnaround Jump Shot',
#      '2PT Field Goal',
#      'In The Paint (Non-RA)',
#      'Center(C)',
#      'Less Than 8 ft.',
#      7,
#      -73,
#      20,
#      1,
#      0,
#      '20171027',
#      'NYK',
#      'BKN'],
#     ['Shot Chart Detail',
#      '0021700073',
#      602,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      4,
#      38,
#      'Made Shot',
#      'Dunk Shot',
#      '2PT Field Goal',
#      'Restricted Area',
#      'Center(C)',
#      'Less Than 8 ft.',
#      1,
#      -1,
#      12,
#      1,
#      1,
#      '20171027',
#      'NYK',
#      'BKN'],
#     ['Shot Chart Detail',
#      '0021700090',
#      10,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      11,
#      19,
#      'Made Shot',
#      'Jump Shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Right Side Center(RC)',
#      '16-24 ft.',
#      19,
#      127,
#      143,
#      1,
#      1,
#      '20171029',
#      'CLE',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700090',
#      22,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      9,
#      59,
#      'Missed Shot',
#      'Jump Shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Right Side(R)',
#      '16-24 ft.',
#      19,
#      161,
#      104,
#      1,
#      0,
#      '20171029',
#      'CLE',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700090',
#      37,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      8,
#      53,
#      'Made Shot',
#      'Jump Shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Right Side Center(RC)',
#      '16-24 ft.',
#      18,
#      123,
#      140,
#      1,
#      1,
#      '20171029',
#      'CLE',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700090',
#      86,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      4,
#      26,
#      'Made Shot',
#      'Jump Shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Left Side(L)',
#      '8-16 ft.',
#      14,
#      -136,
#      61,
#      1,
#      1,
#      '20171029',
#      'CLE',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700090',
#      94,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      3,
#      36,
#      'Made Shot',
#      'Turnaround Jump Shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Right Side(R)',
#      '8-16 ft.',
#      13,
#      96,
#      98,
#      1,
#      1,
#      '20171029',
#      'CLE',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700090',
#      106,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      3,
#      12,
#      'Missed Shot',
#      'Layup Shot',
#      '2PT Field Goal',
#      'Restricted Area',
#      'Center(C)',
#      'Less Than 8 ft.',
#      1,
#      8,
#      17,
#      1,
#      0,
#      '20171029',
#      'CLE',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700090',
#      109,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      3,
#      9,
#      'Missed Shot',
#      'Jump Shot',
#      '3PT Field Goal',
#      'Above the Break 3',
#      'Right Side Center(RC)',
#      '24+ ft.',
#      26,
#      188,
#      180,
#      1,
#      0,
#      '20171029',
#      'CLE',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700090',
#      134,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      1,
#      19,
#      'Missed Shot',
#      'Cutting Layup Shot',
#      '2PT Field Goal',
#      'Restricted Area',
#      'Center(C)',
#      'Less Than 8 ft.',
#      2,
#      -20,
#      10,
#      1,
#      0,
#      '20171029',
#      'CLE',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700090',
#      138,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      0,
#      48,
#      'Made Shot',
#      'Turnaround Jump Shot',
#      '2PT Field Goal',
#      'In The Paint (Non-RA)',
#      'Center(C)',
#      '8-16 ft.',
#      15,
#      66,
#      136,
#      1,
#      1,
#      '20171029',
#      'CLE',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700090',
#      143,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      0,
#      15,
#      'Missed Shot',
#      'Jump Shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Right Side(R)',
#      '16-24 ft.',
#      20,
#      175,
#      114,
#      1,
#      0,
#      '20171029',
#      'CLE',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700090',
#      237,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      2,
#      5,
#      50,
#      'Missed Shot',
#      'Jump Shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Center(C)',
#      '8-16 ft.',
#      15,
#      -35,
#      147,
#      1,
#      0,
#      '20171029',
#      'CLE',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700090',
#      280,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      2,
#      3,
#      32,
#      'Missed Shot',
#      'Jump Shot',
#      '3PT Field Goal',
#      'Above the Break 3',
#      'Center(C)',
#      '24+ ft.',
#      25,
#      72,
#      247,
#      1,
#      0,
#      '20171029',
#      'CLE',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700090',
#      288,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      2,
#      2,
#      39,
#      'Made Shot',
#      'Cutting Dunk Shot',
#      '2PT Field Goal',
#      'Restricted Area',
#      'Center(C)',
#      'Less Than 8 ft.',
#      0,
#      3,
#      6,
#      1,
#      1,
#      '20171029',
#      'CLE',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700090',
#      311,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      2,
#      0,
#      56,
#      'Made Shot',
#      'Layup Shot',
#      '2PT Field Goal',
#      'Restricted Area',
#      'Center(C)',
#      'Less Than 8 ft.',
#      0,
#      8,
#      3,
#      1,
#      1,
#      '20171029',
#      'CLE',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700090',
#      338,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      3,
#      11,
#      25,
#      'Missed Shot',
#      'Tip Layup Shot',
#      '2PT Field Goal',
#      'Restricted Area',
#      'Center(C)',
#      'Less Than 8 ft.',
#      0,
#      0,
#      -6,
#      1,
#      0,
#      '20171029',
#      'CLE',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700090',
#      345,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      3,
#      10,
#      53,
#      'Made Shot',
#      'Reverse Layup Shot',
#      '2PT Field Goal',
#      'Restricted Area',
#      'Center(C)',
#      'Less Than 8 ft.',
#      1,
#      -1,
#      16,
#      1,
#      1,
#      '20171029',
#      'CLE',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700090',
#      354,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      3,
#      10,
#      1,
#      'Made Shot',
#      'Jump Shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Left Side(L)',
#      '8-16 ft.',
#      14,
#      -148,
#      20,
#      1,
#      1,
#      '20171029',
#      'CLE',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700090',
#      371,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      3,
#      8,
#      27,
#      'Missed Shot',
#      'Jump Shot',
#      '3PT Field Goal',
#      'Above the Break 3',
#      'Left Side Center(LC)',
#      '24+ ft.',
#      25,
#      -110,
#      233,
#      1,
#      0,
#      '20171029',
#      'CLE',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700090',
#      397,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      3,
#      6,
#      30,
#      'Made Shot',
#      'Turnaround Jump Shot',
#      '2PT Field Goal',
#      'In The Paint (Non-RA)',
#      'Center(C)',
#      '8-16 ft.',
#      10,
#      -23,
#      107,
#      1,
#      1,
#      '20171029',
#      'CLE',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700090',
#      549,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      8,
#      50,
#      'Missed Shot',
#      'Turnaround Jump Shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Right Side(R)',
#      '8-16 ft.',
#      14,
#      105,
#      106,
#      1,
#      0,
#      '20171029',
#      'CLE',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700090',
#      571,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      6,
#      55,
#      'Missed Shot',
#      'Jump Bank Shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Left Side(L)',
#      '8-16 ft.',
#      15,
#      -122,
#      102,
#      1,
#      0,
#      '20171029',
#      'CLE',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700090',
#      580,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      6,
#      21,
#      'Missed Shot',
#      'Turnaround Jump Shot',
#      '2PT Field Goal',
#      'In The Paint (Non-RA)',
#      'Center(C)',
#      '8-16 ft.',
#      12,
#      48,
#      115,
#      1,
#      0,
#      '20171029',
#      'CLE',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700090',
#      599,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      4,
#      43,
#      'Missed Shot',
#      'Turnaround Jump Shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Right Side(R)',
#      '8-16 ft.',
#      14,
#      100,
#      106,
#      1,
#      0,
#      '20171029',
#      'CLE',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700090',
#      609,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      4,
#      13,
#      'Missed Shot',
#      'Jump Shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Right Side(R)',
#      '8-16 ft.',
#      9,
#      87,
#      41,
#      1,
#      0,
#      '20171029',
#      'CLE',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700090',
#      613,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      3,
#      41,
#      'Made Shot',
#      'Jump Shot',
#      '3PT Field Goal',
#      'Left Corner 3',
#      'Left Side(L)',
#      '24+ ft.',
#      23,
#      -234,
#      50,
#      1,
#      1,
#      '20171029',
#      'CLE',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700090',
#      626,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      2,
#      47,
#      'Made Shot',
#      'Driving Finger Roll Layup Shot',
#      '2PT Field Goal',
#      'Restricted Area',
#      'Center(C)',
#      'Less Than 8 ft.',
#      2,
#      6,
#      28,
#      1,
#      1,
#      '20171029',
#      'CLE',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700090',
#      630,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      2,
#      21,
#      'Made Shot',
#      'Jump Shot',
#      '3PT Field Goal',
#      'Above the Break 3',
#      'Left Side Center(LC)',
#      '24+ ft.',
#      26,
#      -170,
#      207,
#      1,
#      1,
#      '20171029',
#      'CLE',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700094',
#      7,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      11,
#      46,
#      'Made Shot',
#      'Jump Shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Center(C)',
#      '8-16 ft.',
#      15,
#      13,
#      154,
#      1,
#      1,
#      '20171030',
#      'NYK',
#      'DEN'],
#     ['Shot Chart Detail',
#      '0021700094',
#      15,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      10,
#      48,
#      'Missed Shot',
#      'Jump Shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Right Side Center(RC)',
#      '16-24 ft.',
#      16,
#      64,
#      154,
#      1,
#      0,
#      '20171030',
#      'NYK',
#      'DEN'],
#     ['Shot Chart Detail',
#      '0021700094',
#      30,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      9,
#      0,
#      'Made Shot',
#      'Jump Shot',
#      '3PT Field Goal',
#      'Above the Break 3',
#      'Left Side Center(LC)',
#      '24+ ft.',
#      28,
#      -110,
#      265,
#      1,
#      1,
#      '20171030',
#      'NYK',
#      'DEN'],
#     ['Shot Chart Detail',
#      '0021700094',
#      34,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      8,
#      29,
#      'Made Shot',
#      'Dunk Shot',
#      '2PT Field Goal',
#      'Restricted Area',
#      'Center(C)',
#      'Less Than 8 ft.',
#      0,
#      -7,
#      4,
#      1,
#      1,
#      '20171030',
#      'NYK',
#      'DEN'],
#     ['Shot Chart Detail',
#      '0021700094',
#      39,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      7,
#      50,
#      'Made Shot',
#      'Jump Shot',
#      '3PT Field Goal',
#      'Above the Break 3',
#      'Center(C)',
#      '24+ ft.',
#      32,
#      0,
#      322,
#      1,
#      1,
#      '20171030',
#      'NYK',
#      'DEN'],
#     ['Shot Chart Detail',
#      '0021700094',
#      43,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      7,
#      15,
#      'Missed Shot',
#      'Layup Shot',
#      '2PT Field Goal',
#      'Restricted Area',
#      'Center(C)',
#      'Less Than 8 ft.',
#      1,
#      0,
#      11,
#      1,
#      0,
#      '20171030',
#      'NYK',
#      'DEN'],
#     ['Shot Chart Detail',
#      '0021700094',
#      48,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      6,
#      52,
#      'Made Shot',
#      'Jump Shot',
#      '3PT Field Goal',
#      'Above the Break 3',
#      'Right Side Center(RC)',
#      '24+ ft.',
#      26,
#      131,
#      226,
#      1,
#      1,
#      '20171030',
#      'NYK',
#      'DEN'],
#     ['Shot Chart Detail',
#      '0021700094',
#      73,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      4,
#      29,
#      'Missed Shot',
#      'Jump Shot',
#      '3PT Field Goal',
#      'Above the Break 3',
#      'Left Side Center(LC)',
#      '24+ ft.',
#      29,
#      -103,
#      274,
#      1,
#      0,
#      '20171030',
#      'NYK',
#      'DEN'],
#     ['Shot Chart Detail',
#      '0021700094',
#      81,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      3,
#      40,
#      'Missed Shot',
#      'Driving Layup Shot',
#      '2PT Field Goal',
#      'Restricted Area',
#      'Center(C)',
#      'Less Than 8 ft.',
#      1,
#      6,
#      18,
#      1,
#      0,
#      '20171030',
#      'NYK',
#      'DEN'],
#     ['Shot Chart Detail',
#      '0021700094',
#      86,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      3,
#      11,
#      'Missed Shot',
#      'Turnaround Jump Shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Left Side Center(LC)',
#      '16-24 ft.',
#      16,
#      -67,
#      154,
#      1,
#      0,
#      '20171030',
#      'NYK',
#      'DEN'],
#     ['Shot Chart Detail',
#      '0021700094',
#      254,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      2,
#      4,
#      55,
#      'Made Shot',
#      'Jump Bank Shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Right Side(R)',
#      '8-16 ft.',
#      11,
#      96,
#      67,
#      1,
#      1,
#      '20171030',
#      'NYK',
#      'DEN'],
#     ['Shot Chart Detail',
#      '0021700094',
#      286,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      2,
#      2,
#      49,
#      'Made Shot',
#      'Step Back Jump shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Center(C)',
#      '16-24 ft.',
#      17,
#      -33,
#      174,
#      1,
#      1,
#      '20171030',
#      'NYK',
#      'DEN'],
#     ['Shot Chart Detail',
#      '0021700094',
#      302,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      2,
#      1,
#      51,
#      'Made Shot',
#      'Jump Shot',
#      '3PT Field Goal',
#      'Above the Break 3',
#      'Right Side Center(RC)',
#      '24+ ft.',
#      26,
#      111,
#      239,
#      1,
#      1,
#      '20171030',
#      'NYK',
#      'DEN'],
#     ['Shot Chart Detail',
#      '0021700094',
#      325,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      2,
#      0,
#      4,
#      'Made Shot',
#      'Turnaround Jump Shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Right Side(R)',
#      '8-16 ft.',
#      13,
#      136,
#      28,
#      1,
#      1,
#      '20171030',
#      'NYK',
#      'DEN'],
#     ['Shot Chart Detail',
#      '0021700094',
#      342,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      3,
#      11,
#      18,
#      'Missed Shot',
#      'Layup Shot',
# ...
#      'New York Knicks',
#      2,
#      5,
#      15,
#      'Made Shot',
#      'Cutting Dunk Shot',
#      '2PT Field Goal',
#      'Restricted Area',
#      'Center(C)',
#      'Less Than 8 ft.',
#      2,
#      -6,
#      26,
#      1,
#      1,
#      '20180202',
#      'MIL',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700771',
#      273,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      2,
#      4,
#      25,
#      'Missed Shot',
#      'Driving Floating Jump Shot',
#      '2PT Field Goal',
#      'In The Paint (Non-RA)',
#      'Center(C)',
#      '8-16 ft.',
#      9,
#      -30,
#      88,
#      1,
#      0,
#      '20180202',
#      'MIL',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700771',
#      279,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      2,
#      3,
#      44,
#      'Missed Shot',
#      'Jump Shot',
#      '3PT Field Goal',
#      'Above the Break 3',
#      'Right Side Center(RC)',
#      '24+ ft.',
#      26,
#      103,
#      247,
#      1,
#      0,
#      '20180202',
#      'MIL',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700771',
#      330,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      2,
#      0,
#      0,
#      'Missed Shot',
#      'Jump Shot',
#      '3PT Field Goal',
#      'Backcourt',
#      'Back Court(BC)',
#      'Back Court Shot',
#      59,
#      123,
#      586,
#      1,
#      0,
#      '20180202',
#      'MIL',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700771',
#      398,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      3,
#      10,
#      34,
#      'Missed Shot',
#      'Turnaround Jump Shot',
#      '2PT Field Goal',
#      'In The Paint (Non-RA)',
#      'Center(C)',
#      '8-16 ft.',
#      12,
#      57,
#      107,
#      1,
#      0,
#      '20180202',
#      'MIL',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700771',
#      421,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      3,
#      4,
#      54,
#      'Made Shot',
#      'Jump Shot',
#      '2PT Field Goal',
#      'In The Paint (Non-RA)',
#      'Center(C)',
#      '8-16 ft.',
#      13,
#      8,
#      133,
#      1,
#      1,
#      '20180202',
#      'MIL',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700771',
#      512,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      9,
#      20,
#      'Missed Shot',
#      'Turnaround Jump Shot',
#      '2PT Field Goal',
#      'In The Paint (Non-RA)',
#      'Center(C)',
#      'Less Than 8 ft.',
#      4,
#      -49,
#      4,
#      1,
#      0,
#      '20180202',
#      'MIL',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700771',
#      530,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      7,
#      45,
#      'Made Shot',
#      'Putback Layup Shot',
#      '2PT Field Goal',
#      'Restricted Area',
#      'Center(C)',
#      'Less Than 8 ft.',
#      1,
#      10,
#      5,
#      1,
#      1,
#      '20180202',
#      'MIL',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700771',
#      576,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      4,
#      37,
#      'Missed Shot',
#      'Jump Shot',
#      '2PT Field Goal',
#      'In The Paint (Non-RA)',
#      'Center(C)',
#      'Less Than 8 ft.',
#      7,
#      -73,
#      -4,
#      1,
#      0,
#      '20180202',
#      'MIL',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700771',
#      607,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      2,
#      14,
#      'Made Shot',
#      'Cutting Layup Shot',
#      '2PT Field Goal',
#      'Restricted Area',
#      'Center(C)',
#      'Less Than 8 ft.',
#      0,
#      -2,
#      8,
#      1,
#      1,
#      '20180202',
#      'MIL',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700771',
#      610,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      1,
#      43,
#      'Missed Shot',
#      'Jump Shot',
#      '3PT Field Goal',
#      'Above the Break 3',
#      'Left Side Center(LC)',
#      '24+ ft.',
#      28,
#      -137,
#      252,
#      1,
#      0,
#      '20180202',
#      'MIL',
#      'NYK'],
#     ['Shot Chart Detail',
#      '0021700786',
#      7,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      11,
#      40,
#      'Made Shot',
#      'Jump Shot',
#      '3PT Field Goal',
#      'Above the Break 3',
#      'Right Side Center(RC)',
#      '24+ ft.',
#      28,
#      133,
#      257,
#      1,
#      1,
#      '20180204',
#      'NYK',
#      'ATL'],
#     ['Shot Chart Detail',
#      '0021700786',
#      15,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      10,
#      39,
#      'Missed Shot',
#      'Jump Shot',
#      '3PT Field Goal',
#      'Above the Break 3',
#      'Right Side Center(RC)',
#      '24+ ft.',
#      26,
#      100,
#      240,
#      1,
#      0,
#      '20180204',
#      'NYK',
#      'ATL'],
#     ['Shot Chart Detail',
#      '0021700786',
#      19,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      9,
#      59,
#      'Missed Shot',
#      'Jump Shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Right Side Center(RC)',
#      '16-24 ft.',
#      18,
#      104,
#      152,
#      1,
#      0,
#      '20180204',
#      'NYK',
#      'ATL'],
#     ['Shot Chart Detail',
#      '0021700786',
#      21,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      9,
#      52,
#      'Missed Shot',
#      'Dunk Shot',
#      '2PT Field Goal',
#      'Restricted Area',
#      'Center(C)',
#      'Less Than 8 ft.',
#      2,
#      1,
#      29,
#      1,
#      0,
#      '20180204',
#      'NYK',
#      'ATL'],
#     ['Shot Chart Detail',
#      '0021700786',
#      25,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      9,
#      17,
#      'Missed Shot',
#      'Fadeaway Jump Shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Right Side(R)',
#      '8-16 ft.',
#      13,
#      83,
#      101,
#      1,
#      0,
#      '20180204',
#      'NYK',
#      'ATL'],
#     ['Shot Chart Detail',
#      '0021700786',
#      37,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      7,
#      52,
#      'Missed Shot',
#      'Jump Shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Center(C)',
#      '16-24 ft.',
#      18,
#      -42,
#      183,
#      1,
#      0,
#      '20180204',
#      'NYK',
#      'ATL'],
#     ['Shot Chart Detail',
#      '0021700786',
#      53,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      6,
#      3,
#      'Missed Shot',
#      'Jump Shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Right Side Center(RC)',
#      '16-24 ft.',
#      18,
#      63,
#      178,
#      1,
#      0,
#      '20180204',
#      'NYK',
#      'ATL'],
#     ['Shot Chart Detail',
#      '0021700786',
#      208,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      2,
#      6,
#      24,
#      'Missed Shot',
#      'Jump Bank Shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Left Side(L)',
#      '8-16 ft.',
#      12,
#      -109,
#      52,
#      1,
#      0,
#      '20180204',
#      'NYK',
#      'ATL'],
#     ['Shot Chart Detail',
#      '0021700786',
#      212,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      2,
#      6,
#      7,
#      'Made Shot',
#      'Jump Shot',
#      '3PT Field Goal',
#      'Above the Break 3',
#      'Center(C)',
#      '24+ ft.',
#      27,
#      33,
#      271,
#      1,
#      1,
#      '20180204',
#      'NYK',
#      'ATL'],
#     ['Shot Chart Detail',
#      '0021700786',
#      231,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      2,
#      4,
#      14,
#      'Missed Shot',
#      'Jump Shot',
#      '3PT Field Goal',
#      'Above the Break 3',
#      'Center(C)',
#      '24+ ft.',
#      26,
#      67,
#      252,
#      1,
#      0,
#      '20180204',
#      'NYK',
#      'ATL'],
#     ['Shot Chart Detail',
#      '0021700786',
#      307,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      3,
#      11,
#      20,
#      'Made Shot',
#      'Driving Layup Shot',
#      '2PT Field Goal',
#      'In The Paint (Non-RA)',
#      'Center(C)',
#      'Less Than 8 ft.',
#      6,
#      -13,
#      67,
#      1,
#      1,
#      '20180204',
#      'NYK',
#      'ATL'],
#     ['Shot Chart Detail',
#      '0021700786',
#      333,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      3,
#      8,
#      42,
#      'Made Shot',
#      'Driving Hook Shot',
#      '2PT Field Goal',
#      'In The Paint (Non-RA)',
#      'Center(C)',
#      'Less Than 8 ft.',
#      6,
#      47,
#      42,
#      1,
#      1,
#      '20180204',
#      'NYK',
#      'ATL'],
#     ['Shot Chart Detail',
#      '0021700786',
#      369,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      3,
#      4,
#      55,
#      'Missed Shot',
#      'Jump Shot',
#      '3PT Field Goal',
#      'Above the Break 3',
#      'Right Side Center(RC)',
#      '24+ ft.',
#      25,
#      113,
#      227,
#      1,
#      0,
#      '20180204',
#      'NYK',
#      'ATL'],
#     ['Shot Chart Detail',
#      '0021700786',
#      489,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      9,
#      3,
#      'Made Shot',
#      'Jump Shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Center(C)',
#      '16-24 ft.',
#      19,
#      -36,
#      189,
#      1,
#      1,
#      '20180204',
#      'NYK',
#      'ATL'],
#     ['Shot Chart Detail',
#      '0021700786',
#      516,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      6,
#      41,
#      'Made Shot',
#      'Driving Layup Shot',
#      '2PT Field Goal',
#      'Restricted Area',
#      'Center(C)',
#      'Less Than 8 ft.',
#      0,
#      -5,
#      7,
#      1,
#      1,
#      '20180204',
#      'NYK',
#      'ATL'],
#     ['Shot Chart Detail',
#      '0021700786',
#      532,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      6,
#      10,
#      'Missed Shot',
#      'Jump Shot',
#      '3PT Field Goal',
#      'Above the Break 3',
#      'Right Side Center(RC)',
#      '24+ ft.',
#      26,
#      86,
#      248,
#      1,
#      0,
#      '20180204',
#      'NYK',
#      'ATL'],
#     ['Shot Chart Detail',
#      '0021700786',
#      542,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      5,
#      13,
#      'Made Shot',
#      'Jump Shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Right Side(R)',
#      '8-16 ft.',
#      13,
#      133,
#      6,
#      1,
#      1,
#      '20180204',
#      'NYK',
#      'ATL'],
#     ['Shot Chart Detail',
#      '0021700786',
#      588,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      2,
#      57,
#      'Made Shot',
#      'Layup Shot',
#      '2PT Field Goal',
#      'Restricted Area',
#      'Center(C)',
#      'Less Than 8 ft.',
#      2,
#      2,
#      27,
#      1,
#      1,
#      '20180204',
#      'NYK',
#      'ATL'],
#     ['Shot Chart Detail',
#      '0021700786',
#      597,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      1,
#      44,
#      'Made Shot',
#      'Jump Shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Left Side(L)',
#      '8-16 ft.',
#      11,
#      -112,
#      4,
#      1,
#      1,
#      '20180204',
#      'NYK',
#      'ATL'],
#     ['Shot Chart Detail',
#      '0021700786',
#      642,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      4,
#      0,
#      1,
#      'Missed Shot',
#      'Putback Dunk Shot',
#      '2PT Field Goal',
#      'Restricted Area',
#      'Center(C)',
#      'Less Than 8 ft.',
#      0,
#      0,
#      -6,
#      1,
#      0,
#      '20180204',
#      'NYK',
#      'ATL'],
#     ['Shot Chart Detail',
#      '0021700801',
#      16,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      11,
#      13,
#      'Made Shot',
#      'Turnaround Fadeaway shot',
#      '2PT Field Goal',
#      'Mid-Range',
#      'Right Side Center(RC)',
#      '16-24 ft.',
#      16,
#      125,
#      101,
#      1,
#      1,
#      '20180206',
#      'NYK',
#      'MIL'],
#     ['Shot Chart Detail',
#      '0021700801',
#      45,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      1,
#      9,
#      18,
#      'Made Shot',
#      'Jump Shot',
#      '2PT Field Goal',
#      'In The Paint (Non-RA)',
#      'Center(C)',
#      '8-16 ft.',
#      9,
#      29,
#      94,
#      1,
#      1,
#      '20180206',
#      'NYK',
#      'MIL'],
#     ['Shot Chart Detail',
#      '0021700801',
#      186,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      2,
#      11,
#      15,
#      'Made Shot',
#      'Jump Shot',
#      '3PT Field Goal',
#      'Above the Break 3',
#      'Center(C)',
#      '24+ ft.',
#      28,
#      -5,
#      289,
#      1,
#      1,
#      '20180206',
#      'NYK',
#      'MIL'],
#     ['Shot Chart Detail',
#      '0021700801',
#      198,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      2,
#      9,
#      51,
#      'Missed Shot',
#      'Jump Shot',
#      '3PT Field Goal',
#      'Above the Break 3',
#      'Center(C)',
#      '24+ ft.',
#      28,
#      2,
#      284,
#      1,
#      0,
#      '20180206',
#      'NYK',
#      'MIL'],
#     ['Shot Chart Detail',
#      '0021700801',
#      215,
#      204001,
#      'Kristaps Porzingis',
#      1610612752,
#      'New York Knicks',
#      2,
#      8,
#      50,
#      'Made Shot',
#      'Dunk Shot',
#      '2PT Field Goal',
#      'Restricted Area',
#      'Center(C)',
#      'Less Than 8 ft.',
#      1,
#      6,
#      13,
#      1,
#      1,
#      '20180206',
#      'NYK',
#      'MIL']]},
#   {'name': 'LeagueAverages',
#    'headers': ['GRID_TYPE',
#     'SHOT_ZONE_BASIC',
#     'SHOT_ZONE_AREA',
#     'SHOT_ZONE_RANGE',
#     'FGA',
#     'FGM',
#     'FG_PCT'],
#    'rowSet': [['League Averages',
#      'Above the Break 3',
#      'Back Court(BC)',
#      'Back Court Shot',
#      54,
#      3,
#      0.056],
#     ['League Averages',
#      'Above the Break 3',
#      'Center(C)',
#      '24+ ft.',
#      15226,
#      5476,
#      0.36],
#     ['League Averages',
#      'Above the Break 3',
#      'Left Side Center(LC)',
#      '24+ ft.',
#      20499,
#      7292,
#      0.356],
#     ['League Averages',
#      'Above the Break 3',
#      'Right Side Center(RC)',
#      '24+ ft.',
#      19341,
#      6859,
#      0.355],
#     ['League Averages',
#      'Backcourt',
#      'Back Court(BC)',
#      'Back Court Shot',
#      524,
#      5,
#      0.01],
#     ['League Averages',
#      'In The Paint (Non-RA)',
#      'Center(C)',
#      '8-16 ft.',
#      11317,
#      4719,
#      0.417],
#     ['League Averages',
#      'In The Paint (Non-RA)',
#      'Center(C)',
#      'Less Than 8 ft.',
#      18036,
#      6921,
#      0.384],
#     ['League Averages',
#      'In The Paint (Non-RA)',
#      'Left Side(L)',
#      '8-16 ft.',
#      1942,
#      773,
#      0.398],
#     ['League Averages',
#      'In The Paint (Non-RA)',
#      'Right Side(R)',
#      '8-16 ft.',
#      1948,
#      788,
#      0.405],
#     ['League Averages',
#      'Left Corner 3',
#      'Left Side(L)',
#      '24+ ft.',
#      8169,
#      3133,
#      0.384],
#     ['League Averages',
#      'Mid-Range',
#      'Center(C)',
#      '8-16 ft.',
#      2460,
#      1042,
#      0.424],
#     ['League Averages',
#      'Mid-Range',
#      'Center(C)',
#      '16-24 ft.',
#      7197,
#      3007,
#      0.418],
#     ['League Averages',
#      'Mid-Range',
#      'Left Side Center(LC)',
#      '16-24 ft.',
#      6596,
#      2612,
#      0.396],
#     ['League Averages',
#      'Mid-Range',
#      'Left Side(L)',
#      '16-24 ft.',
#      2511,
#      994,
#      0.396],
#     ['League Averages',
#      'Mid-Range',
#      'Left Side(L)',
#      '8-16 ft.',
#      6400,
#      2575,
#      0.402],
#     ['League Averages',
#      'Mid-Range',
#      'Right Side Center(RC)',
#      '16-24 ft.',
#      6809,
#      2662,
#      0.391],
#     ['League Averages',
#      'Mid-Range',
#      'Right Side(R)',
#      '16-24 ft.',
#      2316,
#      903,
#      0.39],
#     ['League Averages',
#      'Mid-Range',
#      'Right Side(R)',
#      '8-16 ft.',
#      6047,
#      2476,
#      0.409],
#     ['League Averages',
#      'Restricted Area',
#      'Center(C)',
#      'Less Than 8 ft.',
#      66875,
#      42188,
#      0.631],
#     ['League Averages',
#      'Right Corner 3',
#      'Right Side(R)',
#      '24+ ft.',
#      7440,
#      3007,
#      0.404]]}]}

# %%
# This Player ID is Brandon Ingram
#get_shot_data(1627742)

# %%
data = json_dat['resultSets'][0]['rowSet']
cols = json_dat['resultSets'][0]['headers']

df = pd.DataFrame.from_records(data, columns=cols)

# %%
df = df.drop(columns=['GRID_TYPE'])

# %%
df.head()
# Out:
#       GAME_ID  GAME_EVENT_ID  PLAYER_ID         PLAYER_NAME     TEAM_ID  \
# 0  0021700015             45     204001  Kristaps Porzingis  1610612752
# 1  0021700015             64     204001  Kristaps Porzingis  1610612752
# 2  0021700015             85     204001  Kristaps Porzingis  1610612752
# 3  0021700015            166     204001  Kristaps Porzingis  1610612752
# 4  0021700015            181     204001  Kristaps Porzingis  1610612752
#
#          TEAM_NAME  PERIOD  MINUTES_REMAINING  SECONDS_REMAINING   EVENT_TYPE  \
# 0  New York Knicks       1                  8                 32  Missed Shot
# 1  New York Knicks       1                  7                 26    Made Shot
# 2  New York Knicks       1                  5                 41  Missed Shot
# 3  New York Knicks       1                  0                 30    Made Shot
# 4  New York Knicks       1                  0                  3    Made Shot
#
#    ... SHOT_ZONE_AREA  SHOT_ZONE_RANGE SHOT_DISTANCE LOC_X LOC_Y  \
# 0  ...      Center(C)  Less Than 8 ft.             5     0    58
# 1  ...   Left Side(L)        16-24 ft.            21  -193    90
# 2  ...      Center(C)          24+ ft.            24     2   249
# 3  ...      Center(C)  Less Than 8 ft.             4   -23    36
# 4  ...      Center(C)        16-24 ft.            18   -28   186
#
#    SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG  GAME_DATE  HTM  VTM
# 0                    1               0   20171019  OKC  NYK
# 1                    1               1   20171019  OKC  NYK
# 2                    1               0   20171019  OKC  NYK
# 3                    1               1   20171019  OKC  NYK
# 4                    1               1   20171019  OKC  NYK
#
# [5 rows x 23 columns]

# %% [markdown]
# # Player List

# %%
players_url = 'https://stats.nba.com/players/list/?Historic=Y'
page = urllib.request.urlopen(players_url)

# %%
soup =
